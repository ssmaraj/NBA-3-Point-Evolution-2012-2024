# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import json
import folium
from folium.plugins import MarkerCluster

# %%
#Load dataset
path = '/Users/shantamaraj/Desktop/Basketball Analytics/Processed Data/nba_updated_coordinates.csv'
df = pd.read_csv(path)

df.head()
# Out:
#    regular_season_index  season_start  season_end season_type  player_id  \
# 0                   0.0          2012        2013     Regular     201142
# 1                   1.0          2012        2013     Regular        977
# 2                   2.0          2012        2013     Regular       2544
# 3                   3.0          2012        2013     Regular     201935
# 4                   4.0          2012        2013     Regular       2546
#
#    rank           player     team_id team  games_played  ...  personal_fouls  \
# 0     1     Kevin Durant  1610612760  OKC            81  ...             143
# 1     2      Kobe Bryant  1610612747  LAL            78  ...             173
# 2     3     LeBron James  1610612748  MIA            76  ...             110
# 3     4     James Harden  1610612745  HOU            78  ...             178
# 4     5  Carmelo Anthony  1610612752  NYK            67  ...             205
#
#    total_points  assist_to_turnover_ratio  steal_to_turnover_ratio  \
# 0          2280                      1.34                     0.41
# 1          2133                      1.63                     0.37
# 2          2036                      2.44                     0.57
# 3          2023                      1.54                     0.48
# 4          1920                      0.98                     0.30
#
#    playoff_index                   country              team_full       state  \
# 0            NaN  United States of America  Oklahoma City Thunder    Oklahoma
# 1            NaN  United States of America     Los Angeles Lakers  California
# 2            NaN  United States of America             Miami Heat     Florida
# 3            NaN  United States of America        Houston Rockets       Texas
# 4            NaN  United States of America        New York Knicks    New York
#
#    latitude  longitude
# 0   35.4634   -97.5151
# 1   34.0430  -118.2673
# 2   25.7814   -80.1870
# 3   29.7508   -95.3621
# 4   40.7505   -73.9934
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (8046, 37)

# %%
#Aggregate data by state and country
state_summary = df.groupby(['country', 'state', 'latitude', 'longitude']).agg({'3_point_feild_goals_attempted': 'mean','3_point_feild_goal_percentage': 'mean'
}).reset_index()

# %%
#Rename columns 
state_summary.rename(columns={
    '3_point_feild_goals_attempted': 'avg_3pa',
    '3_point_feild_goal_percentage': 'avg_3p_pct'}, inplace=True)

state_summary.head()
# Out:
#                     country       state  latitude  longitude     avg_3pa  \
# 0                    Canada     Ontario   43.6435   -79.3791   99.687075
# 1  United States of America     Arizona   33.4458  -112.0712  110.565217
# 2  United States of America  California   34.0430  -118.2673   99.637500
# 3  United States of America  California   37.7680  -122.3877  112.681818
# 4  United States of America  California   38.5802  -121.4998  124.845745
#
#    avg_3p_pct
# 0    0.281299
# 1    0.272248
# 2    0.271632
# 3    0.265259
# 4    0.266176

# %%
import branca.colormap as cm

#Create folium map
# --- Create the base map ---
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4, tiles='CartoDB positron')

#Define a color scale for 3P% accuracy
colormap = cm.LinearColormap(
    colors=['orange', 'yellow', 'lightgreen', 'green'],
    vmin=state_summary['avg_3p_pct'].min(),
    vmax=state_summary['avg_3p_pct'].max(),
    caption='Average 3-Point Accuracy (3P%)')

#Add markers
for _, row in state_summary.iterrows():
    color = colormap(row['avg_3p_pct'])
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['avg_3pa'] / 10,  # scaled by average attempts
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=(
            f"<b>{row['state']}, {row['country']}</b><br>"
            f"Avg 3PA: {row['avg_3pa']:.1f}<br>"
            f"Avg 3P%: {row['avg_3p_pct']:.2%}")).add_to(m)

#Add color legend to map
colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bb9cad74367afb5a0e543f2bf18792c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bb9cad74367afb5a0e543f2bf18792c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bb9cad74367afb5a0e543f2bf18792c = L.map(
#                 &quot;map_8bb9cad74367afb5a0e543f2bf18792c&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1daff32989c1f5b2ecc0d93d09f3a41a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1daff32989c1f5b2ecc0d93d09f3a41a.addTo(map_8bb9cad74367afb5a0e543f2bf18792c);
#
#
#             var circle_marker_9e4ca35b95178dbdf0b68583802f0eb9 = L.circleMarker(
#                 [43.6435, -79.3791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#90ee90ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#90ee90ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.968707482993198, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bb9cad74367afb5a0e543f2bf18792c);
#
#
#         var popup_968aa4ce4a1ffdf5422db79f01985edd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4d1e649dee4e9c6a36e22f1aabf8720 = $(`&lt;div id=&quot;html_d4d1e649dee4e9c6a36e22f1aabf8720&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ontario, Canada&lt;/b&gt;&lt;br&gt;Avg 3PA: 99.7&lt;br&gt;Avg 3P%: 28.13%&lt;/div&gt;`)[0];
#                 popup_968aa4ce4a1ffdf5422db79f01985edd.setContent(html_d4d1e649dee4e9c6a36e22f1aabf8720);
#
#
#
#         circle_marker_9e4ca35b95178dbdf0b68583802f0eb9.bindPopup(popup_968aa4ce4a1ffdf5422db79f01985edd)
#         ;
#
#
#
#
#             var circle_marker_abee3cb278704d109a4bd33093b68508 = L.circleMarker(
#                 [33.4458, -112.0712],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d3f939ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d3f939ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.056521739130435, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bb9cad74367afb5a0e543f2bf18792c);
#
#
#         var popup_8349c6471e8c49f4bbf8c8e3bcfeb532 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac99aae20e497f9cb3614f3685757c03 = $(`&lt;div id=&quot;html_ac99aae20e497f9cb3614f3685757c03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arizona, United States of America&lt;/b&gt;&lt;br&gt;Avg 3PA: 110.6&lt;br&gt;Avg 3P%: 27.22%&lt;/div&gt;`)[0];
#                 popup_8349c6471e8c49f4bbf8c8e3bcfeb532.setContent(html_ac99aae20e497f9cb3614f3685757c03);
#
#
#
#         circle_marker_abee3cb278704d109a4bd33093b68508.bindPopup(popup_8349c6471e8c49f4bbf8c8e3bcfeb532)
#         ;
#
#
#
#
#             var circle_marker_444c3186e315029f93f1e13b12ba750d = L.circleMarker(
#                 [34.043, -118.2673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d7f933ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d7f933ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.963750000000001, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bb9cad74367afb5a0e543f2bf18792c);
#
#
#         var popup_69588fbc826651f0cd8d6b37fc76906d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39d50d1217fbf8d996650612df857560 = $(`&lt;div id=&quot;html_39d50d1217fbf8d99665

# %% [markdown]
# ### Geospatial Visualization: 3-Point Accuracy Across US & Canada (2012–2024)
#
# This map visualizes the geographic distribution of average 3-point shooting performance across the US and Canada between 2012 and 2024.
# Each circle’s **size** represents the average number of 3-point attempts per player (3PA), while its **color** indicates shooting accuracy (3P%), ranging from orange (lower accuracy) to dark green (higher accuracy).
#
# The visualization highlights several key insights:
# - **High-performance regions** such as **California**, **Texas**, and **Ontario (Canada)** exhibit both large and green circles, suggesting a combination of high volume and efficiency in 3-point shooting.
# - **Central and southeastern U.S. states** show smaller, more orange markers, indicating lower accuracy or fewer 3-point attempts overall.
# - The **geographic spread** of 3-point proficiency illustrates how the modern NBA’s perimeter-oriented offense has expanded beyond traditional coastal markets to influence nearly every team in North America.
#
# Overall, this map reinforces how the 3-point shot has become a defining strategic element of basketball across regions, merging efficiency and volume as core indicators of offensive evolution.

# %%
#Aggregate data by team
team_summary = df.groupby(['country', 'state', 'team_full', 'latitude', 'longitude']).agg({'3_point_feild_goals_attempted': 'mean', '3_point_feild_goal_percentage': 'mean'}).reset_index()

#Rename columns
team_summary.rename(columns={'3_point_feild_goals_attempted': 'avg_3pa','3_point_feild_goal_percentage': 'avg_3p_pct'}, inplace=True)

team_summary.head()
# Out:
#                     country       state              team_full  latitude  \
# 0                    Canada     Ontario        Toronto Raptors   43.6435
# 1  United States of America     Arizona           Phoenix Suns   33.4458
# 2  United States of America  California  Golden State Warriors   37.7680
# 3  United States of America  California            LA Clippers   34.0430
# 4  United States of America  California     Los Angeles Lakers   34.0430
#
#    longitude     avg_3pa  avg_3p_pct
# 0   -79.3791   99.687075    0.281299
# 1  -112.0712  110.565217    0.272248
# 2  -122.3877  112.681818    0.265259
# 3  -118.2673   94.138264    0.280360
# 4  -118.2673  106.506024    0.260731

# %%
#Create folium map
m_team = folium.Map(location=[39.8283, -98.5795], zoom_start=4, tiles='CartoDB positron')

#Define color scale for 3P%
colormap = cm.LinearColormap(
    colors=['orange', 'yellow', 'lightgreen', 'green'],
    vmin=team_summary['avg_3p_pct'].min(),
    vmax=team_summary['avg_3p_pct'].max(),
    caption='Average 3-Point Accuracy (3P%)')

#Add team markers
for _, row in team_summary.iterrows():
    color = colormap(row['avg_3p_pct'])
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['avg_3pa'] / 10,  # scaled by average attempts
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=(
            f"<b>{row['team_full']}</b><br>"
            f"{row['state']}, {row['country']}<br>"
            f"Avg 3PA: {row['avg_3pa']:.1f}<br>"
            f"Avg 3P%: {row['avg_3p_pct']:.2%}")).add_to(m_team)

#Add color scale legend
colormap.add_to(m_team)

m_team
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c9ff8842c7a92828c38ebe5b4be282b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c9ff8842c7a92828c38ebe5b4be282b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c9ff8842c7a92828c38ebe5b4be282b = L.map(
#                 &quot;map_1c9ff8842c7a92828c38ebe5b4be282b&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca4be626f7981f23fa6374481ed18514 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca4be626f7981f23fa6374481ed18514.addTo(map_1c9ff8842c7a92828c38ebe5b4be282b);
#
#
#             var circle_marker_af506f85f613cd212fddb0c0e21e2ea6 = L.circleMarker(
#                 [43.6435, -79.3791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#90ee90ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#90ee90ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.968707482993198, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c9ff8842c7a92828c38ebe5b4be282b);
#
#
#         var popup_68267c9dd4613de231caa68d29efd0aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b32acdecf2c298391d1e016538204f05 = $(`&lt;div id=&quot;html_b32acdecf2c298391d1e016538204f05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toronto Raptors&lt;/b&gt;&lt;br&gt;Ontario, Canada&lt;br&gt;Avg 3PA: 99.7&lt;br&gt;Avg 3P%: 28.13%&lt;/div&gt;`)[0];
#                 popup_68267c9dd4613de231caa68d29efd0aa.setContent(html_b32acdecf2c298391d1e016538204f05);
#
#
#
#         circle_marker_af506f85f613cd212fddb0c0e21e2ea6.bindPopup(popup_68267c9dd4613de231caa68d29efd0aa)
#         ;
#
#
#
#
#             var circle_marker_05d094a93aaf83fe084ca989ccc49fee = L.circleMarker(
#                 [33.4458, -112.0712],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d3f939ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d3f939ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.056521739130435, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c9ff8842c7a92828c38ebe5b4be282b);
#
#
#         var popup_253e71bacb13efc0fc6da45e1793cfd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6092ff86c629310c62487c38950bf082 = $(`&lt;div id=&quot;html_6092ff86c629310c62487c38950bf082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Phoenix Suns&lt;/b&gt;&lt;br&gt;Arizona, United States of America&lt;br&gt;Avg 3PA: 110.6&lt;br&gt;Avg 3P%: 27.22%&lt;/div&gt;`)[0];
#                 popup_253e71bacb13efc0fc6da45e1793cfd8.setContent(html_6092ff86c629310c62487c38950bf082);
#
#
#
#         circle_marker_05d094a93aaf83fe084ca989ccc49fee.bindPopup(popup_253e71bacb13efc0fc6da45e1793cfd8)
#         ;
#
#
#
#
#             var circle_marker_4e36cd633d727937f7c27b1afb411f4f = L.circleMarker(
#                 [37.768, -122.3877],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fffa00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fffa00ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.26818181818182, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c9ff8842c7a92828c38ebe5b4be282b);
#
#
#         var popup_ef4089d57a95057da85fc5e5ca9b7d7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd64b89d49a1e744fa8fe82d3acd51a

# %% [markdown]
# ### Team-Level 3-Point Accuracy and Attempt Distribution (2012–2024)
#
# This map visualizes the **average 3-point accuracy (3P%)** and **attempt volume (3PA)** across all NBA teams in the United States and Canada between 2012 and 2024. Each circle represents one NBA franchise, positioned at its geographic coordinates.
#
# - **Color intensity** reflects shooting accuracy— green tones indicate higher 3-point efficiency, while yellow to orange tones show lower accuracy.
# - **Circle size** represents average 3-point attempts per player— larger circles correspond to higher shot volumes.
#
# From this map, we can see that:
# - Teams like the **Golden State Warriors (California)**, **Houston Rockets (Texas)**, and **Toronto Raptors (Canada)** stand out with both high accuracy and attempt rates, illustrating their role in driving the “3-point revolution.”
# - Teams in the Midwest and Southeast show moderate accuracy, suggesting more traditional offensive styles.
# - The overall geographic spread highlights how the 3-point shot has become a **universal element of modern basketball**, transcending regional playstyles.
#
# This visualization provides a clear snapshot of how each team contributes to the league’s long-term shift toward perimeter-oriented offense.

# %%
#Create small random offsets for teams in same state
np.random.seed(42)
team_summary['latitude_jitter'] = team_summary['latitude'] + np.random.uniform(-0.3, 0.3, len(team_summary))
team_summary['longitude_jitter'] = team_summary['longitude'] + np.random.uniform(-0.3, 0.3, len(team_summary))

#Rebuild the map with jittered coordinates
m_team_jitter = folium.Map(location=[39.8283, -98.5795], zoom_start=4, tiles='CartoDB positron')

colormap = cm.LinearColormap(
    colors=['orange', 'yellow', 'lightgreen', 'green'],
    vmin=team_summary['avg_3p_pct'].min(),
    vmax=team_summary['avg_3p_pct'].max(),
    caption='Average 3-Point Accuracy (3P%)')

for _, row in team_summary.iterrows():
    color = colormap(row['avg_3p_pct'])
    folium.CircleMarker(
        location=[row['latitude_jitter'], row['longitude_jitter']],
        radius=row['avg_3pa'] / 10,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=(
            f"<b>{row['team_full']}</b><br>"
            f"{row['state']}, {row['country']}<br>"
            f"Avg 3PA: {row['avg_3pa']:.1f}<br>"
            f"Avg 3P%: {row['avg_3p_pct']:.2%}")).add_to(m_team_jitter)

colormap.add_to(m_team_jitter)
m_team_jitter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba2dd60a2bf392fee707d5c95c42fb91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba2dd60a2bf392fee707d5c95c42fb91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba2dd60a2bf392fee707d5c95c42fb91 = L.map(
#                 &quot;map_ba2dd60a2bf392fee707d5c95c42fb91&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09d2df66894ae8133f600bd2c0cb69db = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09d2df66894ae8133f600bd2c0cb69db.addTo(map_ba2dd60a2bf392fee707d5c95c42fb91);
#
#
#             var circle_marker_b6361fe4e9ec593c972ee7985463764c = L.circleMarker(
#                 [43.56822407130842, -79.31457308885913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#90ee90ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#90ee90ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.968707482993198, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba2dd60a2bf392fee707d5c95c42fb91);
#
#
#         var popup_cc3ebd0ea9355cc8221bde4cc43d2609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5e24b00d0059303476f5df10c9cb6cb = $(`&lt;div id=&quot;html_c5e24b00d0059303476f5df10c9cb6cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toronto Raptors&lt;/b&gt;&lt;br&gt;Ontario, Canada&lt;br&gt;Avg 3PA: 99.7&lt;br&gt;Avg 3P%: 28.13%&lt;/div&gt;`)[0];
#                 popup_cc3ebd0ea9355cc8221bde4cc43d2609.setContent(html_c5e24b00d0059303476f5df10c9cb6cb);
#
#
#
#         circle_marker_b6361fe4e9ec593c972ee7985463764c.bindPopup(popup_cc3ebd0ea9355cc8221bde4cc43d2609)
#         ;
#
#
#
#
#             var circle_marker_5390adfd42220dea2da65f6b848dd80c = L.circleMarker(
#                 [33.71622858384595, -112.26888552578762],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d3f939ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d3f939ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.056521739130435, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba2dd60a2bf392fee707d5c95c42fb91);
#
#
#         var popup_e3a03c4681cc256ba2d30e874b5a58cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edd4ad454bd25cb5ab3541f7c75ad0fc = $(`&lt;div id=&quot;html_edd4ad454bd25cb5ab3541f7c75ad0fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Phoenix Suns&lt;/b&gt;&lt;br&gt;Arizona, United States of America&lt;br&gt;Avg 3PA: 110.6&lt;br&gt;Avg 3P%: 27.22%&lt;/div&gt;`)[0];
#                 popup_e3a03c4681cc256ba2d30e874b5a58cc.setContent(html_edd4ad454bd25cb5ab3541f7c75ad0fc);
#
#
#
#         circle_marker_5390adfd42220dea2da65f6b848dd80c.bindPopup(popup_e3a03c4681cc256ba2d30e874b5a58cc)
#         ;
#
#
#
#
#             var circle_marker_b2ebaef62fc915c4e87bdc1b22214919 = L.circleMarker(
#                 [37.90719636508685, -122.64866904420883],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fffa00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fffa00ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.26818181818182, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba2dd60a2bf392fee707d5c95c42fb91);
#
#
#         var popup_0859d391b021f0b2d9c362dc557b8f9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# ### Adjusted Team-Level Map: Resolving City Overlaps
#
# Because some states and metropolitan areas (such as **California**, **Texas**, and **New York**) host multiple NBA teams, their coordinates originally overlapped on the previous map — making it difficult to distinguish franchises in the same city.
#
# This updated visualization adds a **small coordinate offset (“jitter”)** to each team’s location.
# While the map remains geographically accurate, the jitter separates teams slightly to improve visual clarity and allow each franchise’s 3-point profile to be seen individually.
#
# - Circles now appear as **distinct clusters** in multi-team markets such as Los Angeles (Lakers, Clippers) and New York (Knicks, Nets).
# - The **color scale** still represents 3-point shooting accuracy (3P%), while **circle size** continues to show average attempt volume (3PA).
#
# This refined version emphasizes the **regional clustering of 3-point performance**, illustrating how certain markets dominate perimeter play while others remain more balanced or conservative in shot selection.

# %%
path2 = '/Users/shantamaraj/Desktop/Basketball Analytics/Visualizations/'

m.save(f"{path2}nba_state_3point_distribution.html")
m_team.save(f"{path2}nba_team_3point_accuracy.html")
m_team_jitter.save(f"{path2}nba_team_3point_jittered.html")
